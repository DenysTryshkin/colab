# %% [markdown]
# Вам можуть знадобитись такі символи:
#
#
# Символ | Код
# --- | ---
# $\wedge$ | \\$\wedge\\$
# $\vee$ | \\$\vee\\$
# $\neg$ | \\$\neg\\$
# $\rightarrow$ | \\$\rightarrow\\$
# $\oplus$ | \\$\oplus\\$
# $\equiv$ | \\$\equiv\\$
# $\Leftrightarrow$ | \\$\Leftrightarrow\\$

# %% [markdown]
# ## Завдання 1
# Запишіть наступні висловлювання у математичній формі та складіть для них таблиці істиності:

# %% [markdown]
# a) “Морті прийде на вечірку (A) тоді й тільки тоді, коли Джесіка прийде на вечірку(B), а Рік не прийде(C)”.
#
# A - Морті прийде на вечірку \
# B - Джесіка прийде на вечірку \
# C - Рік не прийде
#
# $X = $ A $\Leftrightarrow$ (B $\wedge$ $\neg$C)
#
# $$
# \begin{array} {|r|r|}\hline
# A & B & C & X \\ \hline
# 1 & 1 & 1 & 0 \\ \hline
# 0 & 1 & 1 & 1 \\ \hline
# 1 & 0 & 1 & 0 \\ \hline
# 0 & 0 & 1 & 1 \\ \hline
# 1 & 1 & 0 & 1 \\ \hline
# 0 & 1 & 0 & 0 \\ \hline
# 1 & 0 & 0 & 0 \\ \hline
# 0 & 0 & 0 & 1 \\ \hline
# \end{array}
# $$

# %% [markdown]
# b) “Якщо ми успішно виконаємо домашнє завдання з математичної логіки (A), то ми отримаємо заліковий бал (B) або візьмемо участь у науковому семінарі (C), водночас якщо ми візьмемо участь у науковому семінарі і отримаємо заліковий бал, то достроково складемо іспит з математичної логіки (D)”.
#
# A - Успішно виконаємо домашнє завдання\
# B - Отримаємо заліковий бал\
# C - Візьмемо участь у науковому семінарі\
# D - Достроково складемо іспит з математичної логіки
#
# $X = $ (A $\rightarrow$(B $\vee$ C )) $\wedge$ ((C $\wedge$ B) $\rightarrow$ D)
#
# $$
# \begin{array} {|r|r|}\hline
# A & B & C & D & X \\ \hline
# 1 & 1 & 1 & 1 & 1 \\ \hline
# 0 & 1 & 1 & 1 & 1 \\ \hline
# 1 & 0 & 1 & 1 & 1 \\ \hline
# 0 & 0 & 1 & 1 & 1 \\ \hline
# 1 & 1 & 0 & 1 & 1 \\ \hline
# 0 & 1 & 0 & 1 & 1 \\ \hline
# 1 & 0 & 0 & 1 & 0 \\ \hline
# 0 & 0 & 0 & 1 & 1 \\ \hline
# 1 & 1 & 1 & 0 & 0 \\ \hline
# 0 & 1 & 1 & 0 & 0 \\ \hline
# 1 & 0 & 1 & 0 & 1 \\ \hline
# 0 & 0 & 1 & 0 & 1 \\ \hline
# 1 & 1 & 0 & 0 & 1 \\ \hline
# 0 & 1 & 0 & 0 & 1 \\ \hline
# 1 & 0 & 0 & 0 & 0 \\ \hline
# 0 & 0 & 0 & 0 & 1 \\ \hline
# \end{array}
# $$

# %% [markdown]
# ## Завдання 2
# Із 40 програмістів 18 володіють мовою Python, 19 — мовою С++, 21 — мовою Java. Відомо, що 10 програмістів знають одночасно Python і С++, 7 — Python і Java, 8 — C++ і Java. Троє програмістів не володіють жодною із мов Python, С++, Java. Знайти кількість програмістів, які одночасно знають усі три мови програмування.

# %% [markdown]
# P — Програмісти, які знають Python \
# C — Програмісти, які знають C++ \
# J — Програмісти, які знають Java \
#
#
# |P| = 18 \
# |C| = 19 \
# |J| = 21 \
# |P ∩ C| = 10 - Python і C++ \
# |P ∩ J| = 7 - Python і Java \
# |C ∩ J| = 8 - C++ і Java \
#
# \
# |P ∩ C ∩ J| = 40 - 3 = 37 - Програмісти, які знають хоча б одну мову \
# Програмісти, що знають усі три мови — |P ∩ C ∩ J| \
#
# Використаємо формулу включень і виключень:
#
# |P ∩ C ∩ J| = |P| + |C| + |J| - |P ∩ C| - |P ∩ J| - |C ∩ J| + |P ∩ C ∩ J|
#
# Підставляємо значення:
# \
# 37 = 18 + 19 + 21 - 10 - 7 - 8 + |P ∩ C ∩ J| \
# 37 = 58 - 25 + |P ∩ C ∩ J| \
# 37 = 33 + |P ∩ C ∩ J| \
# |P ∩ C ∩ J| = 37 - 33 = 4 \
# |P ∩ C ∩ J| = 4
#
# Відповідь: 4 кількість програмістів, які одночасно знають усі три мови програмування.
